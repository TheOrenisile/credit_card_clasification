# %%
# Data Manipulation
import numpy as np
import statistics as st
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.float_format = lambda x: f'{x:0.2f}'

#Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Preprocesing
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.model_selection import RandomizedSearchCV, train_test_split

# Algorithms
import xgboost as xgb
# import lightgbm as lm
# import catboost as cbt
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# Model Evaluation
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, f1_score, recall_score 

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('Preprocessed_data.csv')
data.describe(include='all')
# Out:
#         Unnamed: 0     Age  Annual_Income  Monthly_Inhand_Salary  \
# count      7086.00 7086.00        7086.00                7086.00
# unique         NaN     NaN            NaN                    NaN
# top            NaN     NaN            NaN                    NaN
# freq           NaN     NaN            NaN                    NaN
# mean       3542.50   32.70          10.47                   7.98
# std        2045.70   10.57           0.78                   0.79
# min           0.00   14.00           8.85                   5.72
# 25%        1771.25   24.00           9.84                   7.36
# 50%        3542.50   32.00          10.47                   7.99
# 75%        5313.75   41.00          11.12                   8.62
# max        7085.00   56.00          12.06                   9.59
#
#         Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# count             7086.00          7086.00        7086.00      7086.00
# unique                NaN              NaN            NaN          NaN
# top                   NaN              NaN            NaN          NaN
# freq                  NaN              NaN            NaN          NaN
# mean                 5.70             5.68          15.29         3.98
# std                  2.36             2.06           8.54         2.22
# min                  1.00             1.00           1.00         0.00
# 25%                  4.00             4.00           8.00         2.00
# 50%                  6.00             6.00          15.00         4.00
# 75%                  8.00             7.00          21.00         6.00
# max                 10.00            10.00          33.00         9.00
#
#         Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# count               7086.00                 7086.00               7086.00
# unique                  NaN                     NaN                   NaN
# top                     NaN                     NaN                   NaN
# freq                    NaN                     NaN                   NaN
# mean                  22.27                   13.95                 10.86
# std                   15.02                    6.08                  6.88
# min                    0.00                    0.00                 -6.44
# 25%                   11.00                   10.00                  5.77
# 50%                   19.00                   15.00                  9.79
# 75%                   29.00                   19.00                 15.53
# max                   67.00                   27.00                 36.09
#
#         Num_Credit_Inquiries  Outstanding_Debt  Credit_Utilization_Ratio  \
# count                7086.00           7086.00                   7086.00
# unique                   NaN               NaN                       NaN
# top                      NaN               NaN                       NaN
# freq                     NaN               NaN                       NaN
# mean                    5.82              6.97                     32.22
# std                     3.75              0.96                      5.05
# min                     0.00              3.69                     21.26
# 25%                     3.00              6.45                     28.05
# 50%                     6.00              7.14                     32.20
# 75%                     9.00              7.66                     36.46
# max                    16.00              8.52                     46.59
#
#         Credit_History_Age_Months  Payment_of_Min_Amount  Total_EMI_per_month  \
# count                     7086.00                7086.00              7086.00
# unique                        NaN                    NaN                  NaN
# top                           NaN                    NaN                  NaN
# freq                          NaN                    NaN                  NaN
# mean                       210.44                   0.58                 4.31
# std                         99.72                   0.49                 0.92
# min                          2.00                   0.00                 1.50
# 25%                        131.00                   0.00                 3.68
# 50%                        209.00                   1.00                 4.30
# 75%                        289.75                   1.00                 5.02
# max                        403.00                   1.00                 7.41
#
#         Amount_invested_monthly  Monthly_Balance  Creative_professionals  \
# count                   7086.00          7086.00                 7086.00
# unique                      NaN              NaN                     NaN
# top                         NaN              NaN                     NaN
# freq                        NaN              NaN                     NaN
# mean                       4.81             5.84                    0.19
# std                        0.86             0.44                    0.40
# min                        2.34             4.30                    0.00
# 25%                        4.22             5.58                    0.00
# 50%                        4.80             5.78                    0.00
# 75%                        5.40             6.09                    0.00
# max                        7.13             7.22                    1.00
#
#         Business_professionals  Technical_professionals  \
# count                  7086.00                  7086.00
# unique                     NaN                      NaN
# top                        NaN                      NaN
# freq                       NaN                      NaN
# mean                      0.26                     0.27
# std                       0.44                     0.44
# min                       0.00                     0.00
# 25%                       0.00                     0.00
# 50%                       0.00                     0.00
# 75%                       1.00                     1.00
# max                       1.00                     1.00
#
#         Service_professionals  Early_months  Spring_months  Summer_months  \
# count                 7086.00       7086.00        7086.00        7086.00
# unique                    NaN           NaN            NaN            NaN
# top                       NaN           NaN            NaN            NaN
# freq                      NaN           NaN            NaN            NaN
# mean                     0.21          0.50           0.35           0.15
# std                      0.41          0.50           0.48           0.36
# min                      0.00          0.00           0.00           0.00
# 25%                      0.00          0.00           0.00           0.00
# 50%                      0.00          0.00           0.00           0.00
# 75%                      0.00          1.00           1.00           0.00
# max                      1.00          1.00           1.00           1.00
#
#         Good_credit_mix  Standard_credit_mix  Small_value_payments  \
# count           7086.00              7086.00               7086.00
# unique              NaN                  NaN                   NaN
# top                 NaN                  NaN                   NaN
# freq                NaN                  NaN                   NaN
# mean               0.24                 0.49                  0.40
# std                0.43                 0.50                  0.49
# min                0.00                 0.00                  0.00
# 25%                0.00                 0.00                  0.00
# 50%                0.00                 0.00                  0.00
# 75%                0.00                 1.00                  1.00
# max                1.00                 1.00                  1.00
#
#         Medium_value_payments  Large_value_payments Credit_Score
# count                 7086.00               7086.00         7086
# unique                    NaN                   NaN            3
# top                       NaN                   NaN     Standard
# freq                      NaN                   NaN         3874
# mean                     0.35                  0.11          NaN
# std                      0.48                  0.32          NaN
# min                      0.00                  0.00          NaN
# 25%                      0.00                  0.00          NaN
# 50%                      0.00                  0.00          NaN
# 75%                      1.00                  0.00          NaN
# max                      1.00                  1.00          NaN
